# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import optuna
from optuna.visualization.matplotlib import (plot_contour, plot_edf,
                                             plot_optimization_history,
                                             plot_parallel_coordinate,
                                             plot_param_importances,
                                             plot_slice)

# %%
cwd = os.getcwd()
optuna_directory = "/".join(cwd.split("/")[:-1])
optuna_storage = f"sqlite:///{optuna_directory}/optuna.db"

# %%
optuna_studies = optuna.get_all_study_summaries(storage=optuna_storage)
# study_name = optuna_studies[np.argmax([x.n_trials
#                                        for x in optuna_studies])].study_name
study_name = "res1"
study = optuna.load_study(study_name, storage=optuna_storage)
print(study_name)
# Out:
# res1
# /tmp/ipykernel_256140/1784535663.py:5: FutureWarning: load_study(): Please give all values as keyword arguments. See https://github.com/optuna/optuna/issues/3324 for details.
#   study = optuna.load_study(study_name, storage=optuna_storage)

# %%
_ = plot_optimization_history(study)
# Out:
# /tmp/ipykernel_256140/797317381.py:1: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   _ = plot_optimization_history(study)

# %%
_ = plot_contour(study)
# Out:
# /tmp/ipykernel_256140/4165279352.py:1: ExperimentalWarning: plot_contour is experimental (supported from v2.2.0). The interface can change in the future.
#   _ = plot_contour(study)
# [W 2022-11-14 23:21:55,528] Output figures of this Matplotlib-based `plot_contour` function would be different from those of the Plotly-based `plot_contour`.

# %%
_ = plot_slice(study)
# Out:
# /tmp/ipykernel_256140/695896161.py:1: ExperimentalWarning: plot_slice is experimental (supported from v2.2.0). The interface can change in the future.
#   _ = plot_slice(study)

# %%
_ = plot_param_importances(study)
# Out:
# /tmp/ipykernel_256140/2647532889.py:1: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   _ = plot_param_importances(study)

# %%
plot_param_importances(study,
                       target=lambda t: t.duration.total_seconds(),
                       target_name="duration")
# Out:
# /tmp/ipykernel_256140/1163759875.py:1: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_param_importances(study,
# <AxesSubplot: title={'center': 'Hyperparameter Importances'}, xlabel='Importance for duration', ylabel='Hyperparameter'>

# %%
_ = plot_parallel_coordinate(study)
# Out:
# /tmp/ipykernel_256140/1424205852.py:1: ExperimentalWarning: plot_parallel_coordinate is experimental (supported from v2.2.0). The interface can change in the future.
#   _ = plot_parallel_coordinate(study)

# %%
_ = plot_edf(study)
# Out:
# /tmp/ipykernel_256140/331238534.py:1: ExperimentalWarning: plot_edf is experimental (supported from v2.2.0). The interface can change in the future.
#   _ = plot_edf(study)
